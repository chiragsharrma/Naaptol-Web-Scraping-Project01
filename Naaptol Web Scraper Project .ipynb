# %%
#importing libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
#pulling in the data from website 

URL = 'https://www.naaptol.com/non-calling-tablets/i-kall-entertainment-education-wi-fi-tablet-with-stand-n7/p/12610389.html?ntzoneid=9282&nts=Cat_Now_Trending&ntz=Cat_Now_Trending'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding": "gzip, deflate, br","Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9","DNT":"1","Connection":"close","Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='header').get_text()

price = soup2.find(id='square_Details').get_text()


print(title)
print(price)
# Out:
#      Hi
#
#       Guest
#
#      |
#
#       Log In / Register
#
#      |
#
#
#       Track Order
#
#      |
#
#
#
#       Download App
#
#      |
#
#
#        English
#
#
#        ಕನ್ನಡ
#
#
#        मराठी
#
#
#        हिन्दी
#
#
#        മലയാളം
#
#
#        বাঙালি
#
#
#        தமிழ்
#
#
#        తెలుగు
#
#
#
#
#
#         WE'RE HIRING
#
#
#       Call
#
#        0120-678-7424
#
#       to order
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        Shopping Categories
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Login / Register
#
#
#
#
#
#
#
#
#            +91
#
#
#
#
#
#
#
#
#
#
#
#
#            +91
#
#
#
#             change?
#
#
#
#
#
#
#
#             resend?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          Help :
#
#
#
#         Enter a valid Mobile number for verification.
#
#         Enter One Time Password (OTP) sent to your Mobile number and you account will be verified.
#
#
#
#
#
#
#
#
#
#
#
#          Please Try Again , Time Out!!!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         I Kall Entertainment & Education Wi-Fi Tablet with Stand (N7)
#
#
#
#
#
#
#
#
#          Ideal Tablet for Studies and Entertainment!
#
#
#
#
#
#        Powered by the 1.3 GHz Dual Core Processor, the I Kall Education & Entertainment Tablet (N7) offers quick and superior performance. Moreover, it runs on Google Android Version 6.1 Marshmallow operating system that facilitates better and smooth functioning of the device. The large 17.78 cm TFT screen allows you to enjoy high-quality images and videos. The internal memory of 16GB- expandable up to 32GB provides enough space to store all your multimedia files without deleting anything. The connectivity options of the tablet include Wi-Fi, Bluetooth, USB, OTG, FM and 3G. Moreover, it also comes sturdy stand and Accelerometer & Proximity Sensors.
#
#
#
#
#         Highlights
#
#        :
#
#
#          Work from home can be easily done
#
#
#          Family can enjoy movies at home
#
#
#          Ideal for online education, video calling, entertainment
#
#
#          Comes with stand
#
#
#
#
#         Features
#
#        :
#
#
#          Display
#
#         : 17.78 cm TFT screen (600 x 1024 Pixels)
#
#
#
#          Screen
#
#         : Capacitive touch screen
#
#
#
#          SIM
#
#         : No
#
#
#
#          OS
#
#         : Google Android Version 6.1 Marshmallow
#
#
#
#          Processor
#
#         : 1.3 GHz Quad Core Processor
#
#
#
#          RAM
#
#         : 2 GB
#
#
#
#          Camera
#
#         : Rear 0.3 MP Auto Focus with Flash & Front 2.0 MP
#
#
#
#          Internal Memory
#
#         : 16 GB
#
#
#
#          Expandable Memory
#
#         : up to 32 GB via Micro SD card
#
#
#
#          Connectivity
#
#         : Wi-Fi 802.11b, Bluetooth 4.0
#
#
#
#          Multimedia
#
#         : FMÃ?Â Radio,Ã?Â MusicÃ?Â PlayerÃ?Â &Ã?Â VideoÃ?Â Player
#
#
#
#          Sensors
#
#         : Accelerometer, Proximity Sensors
#
#
#
#          Browser
#
#         : GPRS/EDGE
#
#
#
#          Interface
#
#         : OTG support
#
#
#
#          Ports
#
#         : 1 x Micro USB Port, 3.5 mm Headphone Jack
#
#
#
#          Battery Type
#
#         : Li-ion 3000 mAh, 3.7V DC
#
#
#
#          Battery Backup
#
#         : Working time upto 4 hours & standby time upto 24 hours
#
#
#
#          Size/Dimensions
#
#         : 187 x 106 x 12 mm
#
#
#
#          Weight
#
#         : 286 g
#
#
#
#
#       Product ID:
#
#        12610389
#
#
#
#
#        3999.0
#
#
#
#
#       I Kall Entertainment & Education Wi-Fi Tablet with Stand (N7)
#
#
#
#
#         Seller:
#
#        Alpha Radio Delhi DS
#
#         ⓘ
#
#
#
#
#           Close (X)
#
#
#
#
#
#
#
#
#
#
#
#
#          More Sellers
#
#
#
#
#
#
#
#           Close (x)
#
#
#
#
#
#
#
#
#
#
#         Add in Wishlist
#
#          Please click to add in your Wishlist.
#
#
#
#
#
#
#
#
#
#
#
#
#
#          33%
#
#
#
#
#
#         M.R.P. :
#
#          5,999
#
#
#
#
#
#
#         3,999
#
#          + 201 Shipping
#
#
#
#         (incl. of all taxes)
#
#
#
#          Free Shipping for Diamond Members
#
#
#
#
#
#
#
#
#
#           Spl. Discount:
#
#          Rs.
#
#
#
#
#
#
#
#
#
#
#         Select
#
#          Color
#
#         :
#
#
#
#
#
#
#           White
#
#
#
#
#
#
#
#
#
#
#          Call
#
#           0120-678-7424
#
#          to Order
#
#
#
#
#            Click here to Buy
#
#
#
#
#
#
#
#           COD Available
#
#
#           EMI Available
#
#
#
#
#
#          Terms of Use & Privacy Policy
#
#
#
#
#          :: Terms of Use & Privacy Policy ::
#
#           Close (x)
#
#
#
#
#
#
#
#
#
#
#
#
#           Know availability
#
#          at your location
#
#
#
#
#           Check
#
#
#
#
#         Delivery Pincode:
#
#
#
#
#
#          Change Pincode
#
#
#
#
#
#
#
#
#
#
#
#           Earn
#
#            168
#
#           Payback Points.
#
#
#
#
#
#         Easy buy with EMI starting from
#
#          Rs.493
#
#
#          Know more
#
#
#
#
#
#           Close (x)
#
#
#
#
#
#
#             Banks
#
#
#             3 Months
#
#
#             6 Months
#
#
#             9 Months
#
#
#
#
#             ICICI Credit Card
#
#
#             Rs.1,431
#
#
#             Rs.727
#
#
#             Rs.493
#
#
#
#
#             SBI
#
#
#             Rs.1,433
#
#
#             Rs.729
#
#
#             Rs.495
#
#
#
#
#             Standard Chartered Credit Card
#
#
#             Rs.1,431
#
#
#             Rs.727
#
#
#             Rs.495
#
#
#
#
#             Axis Credit Card
#
#
#             Rs.1,429
#
#
#             Rs.725
#
#
#             Rs.493
#
#
#
#
#             HSBC
#
#
#             Rs.1,430
#
#
#             Rs.726
#
#
#             Rs.494
#
#
#
#
#             Kotak Credit Card
#
#
#             Rs.1,429
#
#
#             Rs.725
#
#
#             Rs.495
#
#
#
#
#             HDFC
#
#
#             Rs.1,431
#
#
#             Rs.727
#
#
#             Rs.495
#
#
#
#
#
#
#
#          Warranty:
#
#         1 Year Manufacturer Warranty on Tablet
#
#         Helpline Number: 1800-120-4934 / 01204731048 Email: helpdeskcutomercare08@gmail.com

# %%
#clean some data to make it readable
price = price.strip()[1:]
title = title.strip()

print(price)
print(title)
# Out:
#  Kall Entertainment & Education Wi-Fi Tablet with Stand (N7)
#
#
#
#
#
#
#
#
#          Ideal Tablet for Studies and Entertainment!
#
#
#
#
#
#        Powered by the 1.3 GHz Dual Core Processor, the I Kall Education & Entertainment Tablet (N7) offers quick and superior performance. Moreover, it runs on Google Android Version 6.1 Marshmallow operating system that facilitates better and smooth functioning of the device. The large 17.78 cm TFT screen allows you to enjoy high-quality images and videos. The internal memory of 16GB- expandable up to 32GB provides enough space to store all your multimedia files without deleting anything. The connectivity options of the tablet include Wi-Fi, Bluetooth, USB, OTG, FM and 3G. Moreover, it also comes sturdy stand and Accelerometer & Proximity Sensors.
#
#
#
#
#         Highlights
#
#        :
#
#
#          Work from home can be easily done
#
#
#          Family can enjoy movies at home
#
#
#          Ideal for online education, video calling, entertainment
#
#
#          Comes with stand
#
#
#
#
#         Features
#
#        :
#
#
#          Display
#
#         : 17.78 cm TFT screen (600 x 1024 Pixels)
#
#
#
#          Screen
#
#         : Capacitive touch screen
#
#
#
#          SIM
#
#         : No
#
#
#
#          OS
#
#         : Google Android Version 6.1 Marshmallow
#
#
#
#          Processor
#
#         : 1.3 GHz Quad Core Processor
#
#
#
#          RAM
#
#         : 2 GB
#
#
#
#          Camera
#
#         : Rear 0.3 MP Auto Focus with Flash & Front 2.0 MP
#
#
#
#          Internal Memory
#
#         : 16 GB
#
#
#
#          Expandable Memory
#
#         : up to 32 GB via Micro SD card
#
#
#
#          Connectivity
#
#         : Wi-Fi 802.11b, Bluetooth 4.0
#
#
#
#          Multimedia
#
#         : FMÃ?Â Radio,Ã?Â MusicÃ?Â PlayerÃ?Â &Ã?Â VideoÃ?Â Player
#
#
#
#          Sensors
#
#         : Accelerometer, Proximity Sensors
#
#
#
#          Browser
#
#         : GPRS/EDGE
#
#
#
#          Interface
#
#         : OTG support
#
#
#
#          Ports
#
#         : 1 x Micro USB Port, 3.5 mm Headphone Jack
#
#
#
#          Battery Type
#
#         : Li-ion 3000 mAh, 3.7V DC
#
#
#
#          Battery Backup
#
#         : Working time upto 4 hours & standby time upto 24 hours
#
#
#
#          Size/Dimensions
#
#         : 187 x 106 x 12 mm
#
#
#
#          Weight
#
#         : 286 g
#
#
#
#
#       Product ID:
#
#        12610389
#
#
#
#
#        3999.0
#
#
#
#
#       I Kall Entertainment & Education Wi-Fi Tablet with Stand (N7)
#
#
#
#
#         Seller:
#
#        Alpha Radio Delhi DS
#
#         ⓘ
#
#
#
#
#           Close (X)
#
#
#
#
#
#
#
#
#
#
#
#
#          More Sellers
#
#
#
#
#
#
#
#           Close (x)
#
#
#
#
#
#
#
#
#
#
#         Add in Wishlist
#
#          Please click to add in your Wishlist.
#
#
#
#
#
#
#
#
#
#
#
#
#
#          33%
#
#
#
#
#
#         M.R.P. :
#
#          5,999
#
#
#
#
#
#
#         3,999
#
#          + 201 Shipping
#
#
#
#         (incl. of all taxes)
#
#
#
#          Free Shipping for Diamond Members
#
#
#
#
#
#
#
#
#
#           Spl. Discount:
#
#          Rs.
#
#
#
#
#
#
#
#
#
#
#         Select
#
#          Color
#
#         :
#
#
#
#
#
#
#           White
#
#
#
#
#
#
#
#
#
#
#          Call
#
#           0120-678-7424
#
#          to Order
#
#
#
#
#            Click here to Buy
#
#
#
#
#
#
#
#           COD Available
#
#
#           EMI Available
#
#
#
#
#
#          Terms of Use & Privacy Policy
#
#
#
#
#          :: Terms of Use & Privacy Policy ::
#
#           Close (x)
#
#
#
#
#
#
#
#
#
#
#
#
#           Know availability
#
#          at your location
#
#
#
#
#           Check
#
#
#
#
#         Delivery Pincode:
#
#
#
#
#
#          Change Pincode
#
#
#
#
#
#
#
#
#
#
#
#           Earn
#
#            168
#
#           Payback Points.
#
#
#
#
#
#         Easy buy with EMI starting from
#
#          Rs.493
#
#
#          Know more
#
#
#
#
#
#           Close (x)
#
#
#
#
#
#
#             Banks
#
#
#             3 Months
#
#
#             6 Months
#
#
#             9 Months
#
#
#
#
#             ICICI Credit Card
#
#
#             Rs.1,431
#
#
#             Rs.727
#
#
#             Rs.493
#
#
#
#
#             SBI
#
#
#             Rs.1,433
#
#
#             Rs.729
#
#
#             Rs.495
#
#
#
#
#             Standard Chartered Credit Card
#
#
#             Rs.1,431
#
#
#             Rs.727
#
#
#             Rs.495
#
#
#
#
#             Axis Credit Card
#
#
#             Rs.1,429
#
#
#             Rs.725
#
#
#             Rs.493
#
#
#
#
#             HSBC
#
#
#             Rs.1,430
#
#
#             Rs.726
#
#
#             Rs.494
#
#
#
#
#             Kotak Credit Card
#
#
#             Rs.1,429
#
#
#             Rs.725
#
#
#             Rs.495
#
#
#
#
#             HDFC
#
#
#             Rs.1,431
#
#
#             Rs.727
#
#
#             Rs.495
#
#
#
#
#
#
#
#          Warranty:
#
#         1 Year Manufacturer Warranty on Tablet
#
#         Helpline Number: 1800-120-4934 / 01204731048 Email: helpdeskcutomercare08@gmail.com
# Hi
#
#       Guest
#
#      |
#
#       Log In / Register
#
#      |
#
#
#       Track Order
#
#      |
#
#
#
#       Download App
#
#      |
#
#
#        English
#
#
#        ಕನ್ನಡ
#
#
#        मराठी
#
#
#        हिन्दी
#
#
#        മലയാളം
#
#
#        বাঙালি
#
#
#        தமிழ்
#
#
#        తెలుగు
#
#
#
#
#
#         WE'RE HIRING
#
#
#       Call
#
#        0120-678-7424
#
#       to order
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        Shopping Categories
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Login / Register
#
#
#
#
#
#
#
#
#            +91
#
#
#
#
#
#
#
#
#
#
#
#
#            +91
#
#
#
#             change?
#
#
#
#
#
#
#
#             resend?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#          Help :
#
#
#
#         Enter a valid Mobile number for verification.
#
#         Enter One Time Password (OTP) sent to your Mobile number and you account will be verified.
#
#
#
#
#
#
#
#
#
#
#
#          Please Try Again , Time Out!!!

# %%
#creating timestamp of data collection

import datetime 
today = datetime.date.today()
print(today)
# Out:
# 2022-08-04

# %%
#creating a csv file

import csv

header = ['title','price','date']

data = [title,price,today]
with open('NaaptolCsvDataset.csv','w',newline = '',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
#using pandas library to read the created data file which is empty right now
import pandas as pd
df = pd.read_csv(r'C:\Users\cs166\NaaptolCsvDataset.csv')
print(df)
# Out:
#                                                title  \
# 0  Hi\n     \n      Guest\n     \n     |\n     \n...
#
#                                                price        date
# 0   Kall Entertainment & Education Wi-Fi Tablet w...  2022-08-04

# %%
#append data to the empty csv file 

with open('NaaptolCsvDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#combining all the actions taken into one function 

def check_price():
    URL = 'https://www.naaptol.com/non-calling-tablets/i-kall-entertainment-education-wi-fi-tablet-with-stand-n7/p/12610389.html?ntzoneid=9282&nts=Cat_Now_Trending&ntz=Cat_Now_Trending'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding": "gzip, deflate, br","Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9","DNT":"1","Connection":"close","Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='header').get_text()

    price = soup2.find(id='square_Details').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime 
    today = datetime.date.today()


    import csv

    header = ['title','price','date']

    data = [title,price,today]
    
    with open('NaaptolCsvDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
#checking and updating price after a certain time in our case its every 24 hours means 86400 seconds

while(True):
    check_price()
    time.sleep(86400)

# %%
#now to again read the relatively new modified file we will use pandas

import pandas as pd
df = pd.read_csv(r'C:\Users\cs166\NaaptolCsvDataset.csv')
print(df)

#MadeByCHIRAG.SHARMA
